# %%
from PIL import Image
import numpy as np
import cv2
import math
import os
from utils import crop_and_save_img

# %%
notebook_path = os.getcwd()
image_name = "IMG_1770"
image_ext = "jpg"
image_path = f"{notebook_path}\images\{image_name}.{image_ext}"

pil_image = Image.open(image_path)

display(pil_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x512 at 0x18F831B3D00>

# %%
crop_and_save_img(pil_image, image_name)

for root, dirs, files in os.walk(f"{notebook_path}\cropped_images"):
    for filename in files:
        print(f"{filename}")
# Out:
# IMG_1770_0.png
# IMG_1770_1.png
# IMG_1770_2.png
# IMG_1770_3.png
# IMG_1770_4.png
# IMG_1770_5.png
# IMG_1770_6.png

# %%
for root, dirs, files in os.walk(f"{notebook_path}\images"):
    for filename in files:
        if(filename.endswith(".jpg")):
            image_name = filename[:-4]
            image_path = f"{notebook_path}\images\{image_name}.jpg"
            pil_image = Image.open(image_path)
            crop_and_save_img(pil_image, image_name)
            print(f"{filename} - cropped")
# Out:
# IMG_1770.jpg - cropped
# IMG_1778_0.jpg - cropped

# %%
for root, dirs, files in os.walk(f"{notebook_path}\cropped_images"):
    for filename in files:
        print(f"{filename}")
# Out:
# IMG_1770_0.png
# IMG_1770_1.png
# IMG_1770_2.png
# IMG_1770_3.png
# IMG_1770_4.png
# IMG_1770_5.png
# IMG_1770_6.png
# IMG_1778_0_0.png
# IMG_1778_0_1.png
# IMG_1778_0_10.png
# IMG_1778_0_11.png
# IMG_1778_0_12.png
# IMG_1778_0_13.png
# IMG_1778_0_14.png
# IMG_1778_0_15.png
# IMG_1778_0_16.png
# IMG_1778_0_17.png
# IMG_1778_0_18.png
# IMG_1778_0_19.png
# IMG_1778_0_2.png
# IMG_1778_0_20.png
# IMG_1778_0_21.png
# IMG_1778_0_22.png
# IMG_1778_0_23.png
# IMG_1778_0_24.png
# IMG_1778_0_25.png
# IMG_1778_0_26.png
# IMG_1778_0_27.png
# IMG_1778_0_28.png
# IMG_1778_0_29.png
# IMG_1778_0_3.png
# IMG_1778_0_30.png
# IMG_1778_0_31.png
# IMG_1778_0_32.png
# IMG_1778_0_33.png
# IMG_1778_0_4.png
# IMG_1778_0_5.png
# IMG_1778_0_6.png
# IMG_1778_0_7.png
# IMG_1778_0_8.png
# IMG_1778_0_9.png
